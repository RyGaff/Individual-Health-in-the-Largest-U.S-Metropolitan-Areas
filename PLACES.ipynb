# %%
# Imports
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# import geopandas as gpd
# from shapely.geometry import Point
from sklearn.cluster import DBSCAN
from sklearn.cluster import HDBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
# ----> 5 import geopandas as gpd
#       6 from shapely.geometry import Point
#       7 from sklearn.cluster import DBSCAN
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# Load the data
#filename = "Nutrition__Physical_Activity__and_Obesity_-_Behavioral_Risk_Factor_Surveillance_System.csv"
filename = "Data/PLACES__Local_Data_for_Better_Health__Census_Tract_Data_2024_release_20241216.csv"
#Features
with open(filename, 'r') as f:
    features = f.readline().strip().split(',')
print(features)

if len(features) == 0:
    print("No features found")
    exit(1)

df = pd.read_csv(filename, names=features, header=1)

# Drop Features
#df = df.drop(['YearEnd', 'Class', 'LocationAbbr', 'Datasource', 'Topic', 'Data_Value_Type', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'DataValueTypeID', 'LocationID', 'StratificationCategoryId1', 'StratificationID1', 'Data_Value_Unit'], axis=1)

print(df.head())
print(df.columns)
# Out:
# ['Year', 'StateAbbr', 'StateDesc', 'CountyName', 'CountyFIPS', 'LocationName', 'DataSource', 'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation', 'TotalPop18plus', 'Geolocation', 'LocationID', 'CategoryID', 'MeasureId', 'DataValueTypeID', 'Short_Question_Text']
#    Year StateAbbr StateDesc        CountyName  CountyFIPS  LocationName  \
# 0  2022        VA  Virginia  Colonial Heights       51570   51570830400
# 1  2022        VA  Virginia           Fairfax       51600   51600300500
# 2  2022        VA  Virginia             Galax       51640   51640070101
# 3  2022        VA  Virginia           Hampton       51650   51650010309
# 4  2022        VA  Virginia           Hampton       51650   51650010312
#
#   DataSource         Category                          Measure  \
# 0      BRFSS       Disability  Hearing disability among adults
# ...

# %%
filtered_df = df[df['StateAbbr'].isin(['VA', 'WV', 'MD', 'DC'])]
dmv_areas = [
    "Loudoun",
    "Falls Church",
    "Alexandria",
    "Fairfax",
    "District of Columbia",
    "Fairfax",
    "Montgomery",
    "Prince William",
    "Prince Georges",
    "Arlington",
    "Calvert",
    "Charles",
    "Frederick",
    "Stafford",
    "Manassas",
    "Manassas Park",
    "Clark",
    "Fauquier",
    "Spotsylvania",
    "Warren",
    "Fredericksburg",
    "Jefferson",
]

#Its probably better to use the FIPS codes in this cases since we have a dataframe with ALL of the Counties
#But this for now I just want to get some stuff down
filtered_df = filtered_df[filtered_df['CountyName'].isin(dmv_areas)]

print(filtered_df.head())
print(filtered_df.shape)
print(filtered_df['Measure'].unique())
print(len(filtered_df['Measure'].unique()))

output_file = 'Data/PLACES_dmv.csv'
filtered_df.to_csv(output_file, index=False)
print(f"Saved to {output_file}")
# Out:
#      Year StateAbbr StateDesc     CountyName  CountyFIPS  LocationName  \
# 1    2022        VA  Virginia        Fairfax       51600   51600300500
# 180  2022        VA  Virginia     Alexandria       51510   51510201202
# 184  2022        VA  Virginia     Alexandria       51510   51510201601
# 185  2022        VA  Virginia     Alexandria       51510   51510200305
# 198  2022        VA  Virginia  Manassas Park       51685   51685920100
#
#     DataSource         Category                          Measure  \
# 1        BRFSS  Health Outcomes             Obesity among adults
# 180      BRFSS  Health Outcomes           Arthritis among adults
# 184      BRFSS       Disability      Any disability among adults
# 185      BRFSS       Disability  Hearing disability among adults
# 198      BRFSS  Health Outcomes             Obesity among adults
#
#     Data_Value_Unit  ... Low_Confidence_Limit  High_Confidence_Limit  \
# 1                 %  ...                 24.1                   36.6
# ...

# %%
new_york_areas = [
    "Bronx",
    "Kings",
    "New York",
    "Queens",
    "Richmond", 
    "Westchester", 
    "Bergen", 
    "Hudson", 
    "Passaic",
    "Rockland", 
    "Putnam",
    "Suffolk", 
    "Nassau",
    "Middlesex",
    "Monmouth",
    "Ocean",
    "Somerset",
    "Essex",
    "Union", 
    "Morris",
    "Sussex",
    "Hunterdon",
    "Pike"]
